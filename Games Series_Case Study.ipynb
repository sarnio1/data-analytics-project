# %% [markdown]
# <a href="https://colab.research.google.com/github/sarnio1/data-analytics-project/blob/main/Games%20Series_Case%20Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Games Series Data

# %% [markdown]
# ##Preparing the Packages

# %%
#import package and its alias

import pandas as pd

# %% [markdown]
# ##Reading and Cleaning the Data

# %%
#import data from Google Sheets

sheet_url = 'https://docs.google.com/spreadsheets/d/1GQmkKv3E3k6_OyTuCxBpd7thWwpve7HJed63Jp_Id3A/edit#gid=1485085913'
sheet_url_trf = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
print(sheet_url_trf)

df = pd.read_csv(sheet_url_trf)
df.head(10)
# Out:
# https://docs.google.com/spreadsheets/d/1GQmkKv3E3k6_OyTuCxBpd7thWwpve7HJed63Jp_Id3A/export?format=csv&gid=1485085913
#                             Name  Sales       Series    Release  \
# 0  PlayerUnknown's Battlegrounds   42.0          NaN  12/1/2017
# 1                      Minecraft   33.0    Minecraft  11/1/2011
# 2                     Diablo III   20.0       Diablo   5/1/2012
# 3                    Garry's Mod   20.0          NaN  11/1/2006
# 4                       Terraria   17.2          NaN   5/1/2011
# 5              World of Warcraft   14.0     Warcraft  11/1/2004
# 6                    Half-Life 2   12.0    Half-Life  11/1/2004
# 7       The Witcher 3: Wild Hunt   12.0  The Witcher   5/1/2015
# 8                      StarCraft   11.0    StarCraft   3/1/1998
# 9                       The Sims   11.0     The Sims   2/1/2000
#
#                   Genre               Developer               Publisher
# 0         Battle royale            PUBG Studios                 Krafton
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       177 non-null    object
#  1   Sales      177 non-null    float64
#  2   Series     141 non-null    object
#  3   Release    177 non-null    object
#  4   Genre      177 non-null    object
#  5   Developer  177 non-null    object
#  6   Publisher  177 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 9.8+ KB

# %% [markdown]
# The data type of 'Release' is incorrect. It is formatted as an object instead of datetime, so we will change it.

# %%
#change data type

df_cleaned = df.copy()
df_cleaned['Release'] = pd.to_datetime(df_cleaned['Release'])
print(df_cleaned.info())
df_cleaned.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       177 non-null    object
#  1   Sales      177 non-null    float64
#  2   Series     141 non-null    object
#  3   Release    177 non-null    datetime64[ns]
#  4   Genre      177 non-null    object
#  5   Developer  177 non-null    object
#  6   Publisher  177 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 9.8+ KB
# None
#                             Name  Sales     Series    Release  \
# 0  PlayerUnknown's Battlegrounds   42.0        NaN 2017-12-01
# 1                      Minecraft   33.0  Minecraft 2011-11-01
# 2                     Diablo III   20.0     Diablo 2012-05-01
# 3                    Garry's Mod   20.0        NaN 2006-11-01
# 4                       Terraria   17.2        NaN 2011-05-01
#
# ...

# %% [markdown]
# Now, the 'Release' data has been formatted as datetime data type.

# %%
#check typo by counting the amount of variety of the data


for col_name in ['Genre', 'Developer', 'Publisher']:
        print(df_cleaned[col_name].value_counts(), '\n')
# Out:
# Real-time strategy                        26
# First-person shooter                      19
# Action role-playing                       12
# Construction and management simulation     9
# Role-playing game                          8
#                                           ..
# Action role-playing game                   1
# Maze, arcade                               1
# Action-adventure, platformer               1
# Action-adventure, Survival                 1
# Space combat simulation                    1
# Name: Genre, Length: 61, dtype: int64
#
# Blizzard Entertainment             10
# Maxis                               6
# Paradox Development Studio          5
# id Software                         4
# Westwood Studios                    4
#                                    ..
# Kojima Productions                  1
# Edmund McMillen & Florian Himsl     1
# Landfall Games                      1
# Keen Software House                 1
# Microsoft                           1
# ...

# %% [markdown]
# The data is large in variety.

# %%
#check duplicated data

df_cleaned['Name'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 172    False
# 173    False
# 174    False
# 175     True
# 176     True
# Name: Name, Length: 177, dtype: bool

# %% [markdown]
# There are 2 rows where duplicated data exist, we are going to remove these duplicated data while keeping the original ones.

# %%
#remove duplicated data

df_removed = df_cleaned.drop_duplicates(subset=['Name'], keep='first')
df_removed.tail()
# Out:
#                                      Name  Sales          Series    Release  \
# 170                              Vietcong    1.0        Vietcong 2003-03-01
# 171    Warhammer Online: Age of Reckoning    1.0       Warhammer 2008-09-01
# 172        Who Wants to Be a Millionaire?    1.0             NaN 1999-11-01
# 173  Wing Commander 3: Heart of the Tiger    1.0  Wing Commander 1994-12-01
# 174                            Zoo Tycoon    1.0      Zoo Tycoon 2001-10-01
#
#                        Genre             Developer                   Publisher
# 170         Tactical shooter              Pterodon     Gathering of Developers
# 171                   MMORPG  Mythic Entertainment             Electronic Arts
# 172              Trivia game           Jellyvision  Disney Interactive Studios
# 173  Space combat simulation        Origin Systems             Electronic Arts
# 174      Business simulation             Microsoft             Blue Fang Games

# %%
#fill blank data in column 'Series'

df_replaced = df_removed.replace('',np.nan).fillna('-')
df_replaced.head()
# Out:
#                             Name  Sales     Series    Release  \
# 0  PlayerUnknown's Battlegrounds   42.0          - 2017-12-01
# 1                      Minecraft   33.0  Minecraft 2011-11-01
# 2                     Diablo III   20.0     Diablo 2012-05-01
# 3                    Garry's Mod   20.0          - 2006-11-01
# 4                       Terraria   17.2          - 2011-05-01
#
#                  Genre               Developer               Publisher
# 0        Battle royale            PUBG Studios                 Krafton
# 1    Sandbox, survival          Mojang Studios          Mojang Studios
# 2  Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 3              Sandbox       Facepunch Studios                   Valve
# 4     Action-adventure                Re-Logic                Re-Logic

# %% [markdown]
# Now, the data has been cleaned. We have changed the type of each data properly (changing the string data in column 'Release' with datetime format) and managed to identify duplicated data in column 'Name'.The reason we tested only the 'Name' column is that it contains unique values that is not repeated in the list. Lastly, we fill the blank rows in column 'Series' with "-" where the game has no series.

# %% [markdown]
# ##Explroratory Data Analysis

# %% [markdown]
# ###Which game is the oldest and the newest in the dataset?

# %%
df_replaced.sort_values(by='Release').head(3)
# Out:
#                                        Name  Sales                Series  \
# 133                                 Hydlide    1.0               Hydlide
# 34   Where in the World Is Carmen Sandiego?    4.0       Carmen Sandiego
# 88                     International Karate    1.5  International Karate
#
#        Release                Genre                              Developer  \
# 133 1984-12-01  Action role-playing  Technology and Entertainment Software
# 34  1985-06-01          Educational                             Broderbund
# 88  1985-11-01             Fighting                               System 3
#
#                                  Publisher
# 133  Technology and Entertainment Software
# 34                              Broderbund
# 88                                    Epyx

# %% [markdown]
# The oldest game in the dataset is Hydlide, as it was released in 1984.

# %%
df_replaced.sort_values(by='Release', ascending=False).head(3)
# Out:
#                    Name  Sales          Series    Release  \
# 20              Valheim    6.0               - 2021-02-01
# 27       Cyberpunk 2077    4.5               - 2020-12-01
# 110  Crusader Kings III    1.0  Crusader Kings 2020-09-01
#
#                    Genre                   Developer                Publisher
# 20              Survival                   Iron Gate  Coffee Stain Publishing
# 27   Action role-playing              CD Projekt Red               CD Projekt
# 110       Grand strategy  Paradox Development Studio      Paradox Interactive

# %% [markdown]
# Whereas the newest game in the dataset is Valheim. It was released in 2021.

# %% [markdown]
# ###Which publisher released most of the game?

# %%
print(df_replaced['Publisher'].value_counts())
# Out:
# Electronic Arts           19
# Blizzard Entertainment     8
# Paradox Interactive        7
# Activision                 6
# GT Interactive             5
#                           ..
# Landfall Games             1
# Headup Games               1
# Atari, Inc                 1
# Konami                     1
# Blue Fang Games            1
# Name: Publisher, Length: 96, dtype: int64

# %% [markdown]
# The publisher that released the most games in the dataset is Electronic Arts, with a total of 19 games.

# %% [markdown]
# ###Which developer developed most of the games?

# %%
print(df_replaced['Developer'].value_counts())
# Out:
# Blizzard Entertainment             8
# Maxis                              6
# Paradox Development Studio         5
# id Software                        4
# Westwood Studios                   4
#                                   ..
# Kojima Productions                 1
# Edmund McMillen & Florian Himsl    1
# Landfall Games                     1
# Keen Software House                1
# Microsoft                          1
# Name: Developer, Length: 109, dtype: int64

# %% [markdown]
# The developer that developed the most games in the dataset is Blizzard Entertainment, with a total of 8 games.

# %% [markdown]
# ###Which series has the most sales?

# %%
agg_sales = df_replaced.groupby('Series', as_index=False).agg({'Sales':'sum'}).sort_values(by='Sales', ascending=False)
agg_sales.head()
# Out:
#        Series  Sales
# 0           -  156.1
# 48  Minecraft   33.0
# 23     Diablo   26.0
# 76   The Sims   24.0
# 37  Half-Life   21.0

# %% [markdown]
# The series that have the most sales in the dataset is Minecraft, with a total sales of 33.0.

# %% [markdown]
# ###Which series have the most games?

# %%
agg_games = df_replaced.groupby('Series', as_index=False).agg({'Name':'nunique'}).sort_values(by='Name', ascending=False)
agg_games.head()
# Out:
#                Series  Name
# 0                   -    36
# 14  Command & Conquer     5
# 69          StarCraft     4
# 3      Age of Empires     4
# 13       Civilization     4

# %% [markdown]
# The series that have the most games in the dataset is Command & Conquer, with a total games of 5.

# %%
#export file

from google.colab import files
df_replaced.to_csv('Games Series_Case Study1.csv')
files.download('Games Series_Case Study1.csv')

# %%
url = 'https://docs.google.com/spreadsheets/d/15DKEJWrcCVTEamYBZMHIqlnM7j6GZwKVPtji0NucFwg/edit?usp=sharing'
print(url)
# Out:
# https://docs.google.com/spreadsheets/d/15DKEJWrcCVTEamYBZMHIqlnM7j6GZwKVPtji0NucFwg/edit?usp=sharing

# %% [markdown]
# One can access the cleaned file by clicking the link above.
